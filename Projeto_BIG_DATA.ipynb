# %% [markdown]
# <a href="https://colab.research.google.com/github/DaviGuto/Projeto-Big-Data/blob/main/Projeto_BIG_DATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from imblearn.under_sampling import RandomUnderSampler
import xgboost as xgb
from sklearn.ensemble import AdaBoostClassifier

# %%
def chikungunyaBinaria(chikungunya):
    if chikungunya == 13.0:
        return 1
    else:
        return 0

# %% [markdown]
# #Dataset (Chikungunya) Obtido por: https://data.mendeley.com/datasets/2d3kr8zynf/4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Projeto BIG DATA/chikungunya.csv")
dataframe.head(15)
# Out:
# <ipython-input-46-e70714f33be4>:1: DtypeWarning:
#
# Columns (26,54,56) have mixed types. Specify dtype option on import or set low_memory=False.
#     NU_NOTIFIC  TP_NOT  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 0       486539       2  16/04/2015   201515    2015         13      130260
# 1       479427       2  06/03/2015   201509    2015         13      130260
# 2       511511       2  10/08/2015   201532    2015         13      130260
# 3       489046       2  13/05/2015   201519    2015         13      130260
# 4       487298       2  03/04/2015   201513    2015         13      130260
# 5       502506       2  04/08/2015   201531    2015         13      130260
# 6       499727       2  24/07/2015   201529    2015         13      130260
# 7       499728       2  24/07/2015   201529    2015         13      130260
# 8       509027       2  29/08/2015   201534    2015         13      130260
# 9       547202       2  30/12/2015   201552    2015         13      130260
# ...

# %%
dataframe = dataframe.dropna(how='all', axis=1)

sintomasParaInternacao = ['FEBRE', 'MIALGIA', 'CEFALEIA', 'EXANTEMA', 'VOMITO', 'NAUSEA', 'DOR_COSTAS', 'CONJUNTVIT', 'ARTRITE',
                          'ARTRALGIA', 'PETEQUIA_N', 'DOR_RETRO']

# %%
df = dataframe.dropna(subset=sintomasParaInternacao )
df = df.dropna(subset=['CLASSI_FIN'])

df['CLASSI_FIN'] = df['CLASSI_FIN'].apply(chikungunyaBinaria)

df['HOSPITALIZ'] = pd.to_numeric(df['HOSPITALIZ'], errors='coerce')
df = df.drop(df[df['HOSPITALIZ'] == 9.0].index)


x = df[sintomasParaInternacao]
y = df['CLASSI_FIN']

x , y = RandomUnderSampler(random_state = 42).fit_resample(x, y)

# %%
treino_x, teste_x, treino_y, teste_y = train_test_split(x, y, test_size= 0.3, random_state= 42)

modelo = AdaBoostClassifier()

modelo.fit(treino_x, treino_y)

previsao = modelo.predict(teste_x)



print(classification_report(teste_y, previsao))
print(confusion_matrix(teste_y, previsao))
print(df['CLASSI_FIN'].value_counts())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.71      0.73      1629
#            1       0.72      0.77      0.74      1596
#
#     accuracy                           0.74      3225
#    macro avg       0.74      0.74      0.74      3225
# weighted avg       0.74      0.74      0.74      3225
#
# [[1150  479]
#  [ 367 1229]]
# 1    6676
# 0    5375
# Name: CLASSI_FIN, dtype: int64

# %%
df.head(15)
# Out:
#      NU_NOTIFIC  TP_NOT  DT_NOTIFIC  SEM_NOT  NU_ANO  SG_UF_NOT  ID_MUNICIP  \
# 130      648366       2  04/08/2015   201531    2015         13      130260
# 173      101222       2  02/08/2016   201631    2016         13      130080
# 174      577900       2  17/03/2016   201611    2016         13      130260
# 175      591681       2  31/10/2016   201644    2016         13      130260
# 176      564083       2  16/05/2016   201620    2016         13      130260
# 177      564410       2  21/06/2016   201625    2016         13      130260
# 182      564058       2  02/06/2016   201622    2016         13      130260
# 183      564059       2  02/06/2016   201622    2016         13      130260
# 184      565575       2  23/06/2016   201625    2016         13      130260
# 186      557281       2  19/05/2016   201620    2016         13      130260
# 189      101023       2  14/10/2016   201641    2016         13      130080
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12051 entries, 130 to 18791
# Data columns (total 83 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   NU_NOTIFIC  12051 non-null  int64
#  1   TP_NOT      12051 non-null  int64
#  2   DT_NOTIFIC  12051 non-null  object
#  3   SEM_NOT     12051 non-null  int64
#  4   NU_ANO      12051 non-null  int64
#  5   SG_UF_NOT   12051 non-null  int64
#  6   ID_MUNICIP  12051 non-null  int64
#  7   ID_REGIONA  12042 non-null  float64
#  8   ID_UNIDADE  12051 non-null  int64
#  9   DT_SIN_PRI  12051 non-null  object
#  10  SEM_PRI     12051 non-null  int64
#  11  DT_NASC     11795 non-null  object
#  12  NU_IDADE_N  12051 non-null  int64
#  13  CS_SEXO     12049 non-null  object
#  14  CS_GESTANT  12050 non-null  float64
#  15  CS_RACA     12026 non-null  float64
#  16  CS_ESCOL_N  9513 non-null   float64
#  17  SG_UF       12049 non-null  float64
#  18  ID_MN_RESI  12051 non-null  int64
# ...

# %%
# !pip install plotly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import plotly.graph_objs as go
import plotly.io as pio
import plotly.offline as py
import plotly.express as px
pio.renderers.default = ('colab')

# %%
# Convertendo as colunas de data para o formato datetime
df['DT_OBITO'] = pd.to_datetime(df['DT_OBITO'])

# Contando o número de ocorrências de mortes e não mortes
mortes = df['DT_OBITO'].notnull().sum()
nao_mortes = df['DT_OBITO'].isnull().sum()
# Out:
# <ipython-input-54-ea832e3a9562>:2: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %%
# Filtrando o dataframe apenas para casos de Chikungunya
df_chikungunya = df[df['CLASSI_FIN'] == 1]

# Contando o número de ocorrências de mortes e não mortes
mortes = df_chikungunya['DT_OBITO'].notnull().sum()
nao_mortes = df_chikungunya['DT_OBITO'].isnull().sum()

# Criando o gráfico de pizza
labels = ['Mortes', 'Não Mortes']
valores = [mortes, nao_mortes]

cores = ['#B71C1C', '#1977D2']

trace = go.Pie(labels=labels,
               values=valores,
               marker={'colors': cores},
               hole=0.5,
               direction='clockwise')

# Armazenando dentro de uma lista
data = [trace]

# Criando layout
layout = go.Layout(title='Comparação de Mortes e Não Mortes pela Chikungunya',
                   paper_bgcolor='rgb(54,58,61)',
                   plot_bgcolor='rgb(54,58,61)',
                   font_color='white',
                   annotations=[
                       dict(
                           x=0.5,  # Coordenada x do texto
                           y=0.5,  # Coordenada y do texto
                           text='Total: 6.676 Casos',  # Texto a ser exibido
                           showarrow=False,
                           font=dict(
                               size=14,
                               color='white'
                           )
                       )
                   ])

# Criando figura que será exibida
fig = go.Figure(data=data, layout=layout)

# Exibindo o gráfico
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
# Filtrar casos de Chikungunya
chikung = df['CLASSI_FIN'] == 1
df_chikungunya = df[chikung]

# Contar a quantidade de casos de Chikungunya por ano usando numpy
unique_years, counts = np.unique(df_chikungunya['NU_ANO'], return_counts=True)

# Criar DataFrame com os resultados
contagem_por_ano = pd.DataFrame({'NU_ANO': unique_years, 'Cont': counts})

# %%
# Plotar o gráfico de barras
dados_bar = [go.Bar(x=contagem_por_ano['NU_ANO'],
               y=contagem_por_ano['Cont'],
               marker = {'color' : '#B71C1C'})]


#criando layout
config_lay_bar = go.Layout(title='Casos de Chikungunya Por Ano',
                           yaxis={'title': 'Numero de Casos'},
                           xaxis={'title': 'Período'},
                           paper_bgcolor='rgb(54,58,61)',
                           plot_bgcolor='rgb(54,58,61)',
                           font_color='white'
                           )

#objeto figura
fig1 = go.Figure(data=dados_bar, layout=config_lay_bar)

#plotando o grafico
py.iplot(fig1)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Substituindo os valores nulos por "I" na coluna "CS_SEXO"
df['CS_SEXO'] = df['CS_SEXO'].fillna('I')

# Calcular a contagem de valores na coluna
contagem = df['CS_SEXO'].value_counts()

# Somar a contagem de valores
soma = contagem.sum()

print(contagem)
print("Soma:", soma)
# Out:
# F    7476
# M    4565
# I      10
# Name: CS_SEXO, dtype: int64
# Soma: 12051

# %%
# Calcular a contagem de valores na coluna CS_SEXO para casos positivos
contagem = df_chikungunya['CS_SEXO'].value_counts()

# Criar os dados para o gráfico de pizza
labels = contagem.index.tolist()
valores = contagem.values.tolist()
cores = ['#B71C1C', '#1977D2', 'grey']

trace = go.Pie(labels=labels,
               values=valores,
               marker={'colors': cores},
               direction='clockwise')

# Armazenar dentro de uma lista
data = [trace]

# Criar layout
layout_pie1 = go.Layout(title='Distribuição de Gênero em Casos de Chikungunya',
                        paper_bgcolor='rgb(54,58,61)',
                        plot_bgcolor='rgb(54,58,61)',
                        font_color='white')

# Criar figura que será exibida
fig2 = go.Figure(data=data, layout=layout_pie1)

# Exibir o gráfico
py.iplot(fig2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Agrupar os dados por ano e contar o número de casos positivos e negativos
dados_por_ano = df.groupby('NU_ANO')['CLASSI_FIN'].value_counts().unstack()

# Criar o gráfico de linha
fig3 = go.Figure()
fig3.add_trace(go.Scatter(x=dados_por_ano.index, y=dados_por_ano[1], mode='lines', name='Chikungunya',
                          line=dict(color='#B71C1C')))
fig3.add_trace(go.Scatter(x=dados_por_ano.index, y=dados_por_ano[0], mode='lines', name='Outros Vírus',
                          line=dict(color='#1977D2')))

# Definir layout do gráfico
fig3.update_layout(
    title='Evolução dos Casos de Chikungunya ao Longo dos Anos',
    xaxis=dict(title='Ano'),
    yaxis=dict(title='Número de Casos'),
    paper_bgcolor='rgb(54,58,61)',
    plot_bgcolor='rgb(54,58,61)',
    font_color='white')

# Exibir o gráfico
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
casos_positivos = df['CLASSI_FIN'].value_counts()[1]
print("Quantidade de casos positivos:", casos_positivos)
# Out:
# Quantidade de casos positivos: 6676

# %%
# Criando uma lista vazia para armazenar os dados dos sintomas
dados_sintomas = []

# Iterando sobre cada sintoma
for sintoma in sintomasParaInternacao:
    # Filtrando os dados para casos positivos de chikungunya (CLASSI_FIN = 1)
    positivo = df[df['CLASSI_FIN'] == 1][sintoma].value_counts().get(1.0, 0)

    # Filtrando os dados para casos negativos de chikungunya (CLASSI_FIN = 0)
    negativo = df[df['CLASSI_FIN'] == 0][sintoma].value_counts().get(2.0, 0)

    # Adicionando os dados na lista
    dados_sintomas.append([sintoma, positivo, negativo])

# Criando um DataFrame com os dados dos sintomas
df_sintomas = pd.DataFrame(dados_sintomas, columns=['Sintoma', 'Positivo', 'Negativo'])

# Criando um gráfico de barras empilhadas
fig4 = go.Figure(data=[
    go.Bar(name='Positivo', x=df_sintomas['Sintoma'], y=df_sintomas['Positivo'], marker=dict(color='#B71C1C')),
    go.Bar(name='Negativo', x=df_sintomas['Sintoma'], y=df_sintomas['Negativo'], marker=dict(color='#1977D2'))
])

# Atualizando o layout do gráfico
fig4.update_layout(title='Comparação de Casos De Chikungunya Positivos e Negativos por Sintoma',
                  xaxis_title='Sintoma',
                  yaxis_title='Quantidade de Casos',
                  paper_bgcolor='rgb(54,58,61)',
                  plot_bgcolor='rgb(54,58,61)',
                  font_color='white')

# Exibindo o gráfico
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Filtrando os dados para casos positivos de chikungunya
casos_positivos = df[df['CLASSI_FIN'] == 1].copy()

# Convertendo as colunas de data para o tipo datetime
casos_positivos.loc[:, 'DT_NOTIFIC'] = pd.to_datetime(casos_positivos['DT_NOTIFIC'], format='%d/%m/%Y', dayfirst=True, errors='coerce')
casos_positivos.loc[:, 'DT_ENCERRA'] = pd.to_datetime(casos_positivos['DT_ENCERRA'], format='%d/%m/%Y', dayfirst=True, errors='coerce')

# Excluindo linhas vazias
casos_positivos = casos_positivos.dropna(subset=['DT_NOTIFIC', 'DT_ENCERRA'])

# Cálculo do período de doença
casos_positivos.loc[:, 'Periodo_Doenca'] = casos_positivos['DT_ENCERRA'] - casos_positivos['DT_NOTIFIC']
casos_positivos.loc[:, 'Periodo_Doenca_Dias'] = casos_positivos['Periodo_Doenca'] / pd.Timedelta(days=1)

# Plotando o gráfico de caixa
fig5 = px.box(casos_positivos, y='Periodo_Doenca_Dias', title='Gráfico de Caixa: Período de Doença')
fig5.update_yaxes(title='Período de Doença')

# Alterando a cor do boxplot
fig5.data[0]['marker']['color'] = '#1977D2'

# Modificando o background do gráfico
fig5.update_layout(paper_bgcolor='rgb(54,58,61)',
                  plot_bgcolor='rgb(54,58,61)',
                  font_color='white')

# Exibindo o gráfico
fig5.show()
# Out:
# <ipython-input-63-2d4ede988a47>:7: DeprecationWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# <ipython-input-63-2d4ede988a47>:8: DeprecationWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...

# %%
modelos = ['Adaboost', 'DecisionTree', 'RandomForest', 'Logistic Regression', 'xgboost']
precision_class0 = np.array([0.77, 0.78, 0.77, 0.77, 0.78])
precision_class1 = np.array([0.71, 0.70, 0.70, 0.71, 0.70])

average_precision = (precision_class0 + precision_class1) / 2

fig6 = go.Figure()

fig6.add_trace(go.Bar(
    y=modelos,
    x=precision_class0,
    name='Precision Class 0',
    orientation='h',
    marker_color='#1977D2'
))

fig6.add_trace(go.Bar(
    y=modelos,
    x=precision_class1,
    name='Precision Class 1',
    orientation='h',
    marker_color='#B71C1C'
))

fig6.add_trace(go.Scatter(
    y=modelos,
    x=average_precision,
    mode='lines',
    name='Average Precision',
    line=dict(color='#D4AC0D', width=2)
))

fig6.update_layout(
    title='Comparação de Desempenho dos Modelos',
    xaxis_title='Precision',
    yaxis_title='Modelos',
    yaxis=dict(autorange="reversed"),
    paper_bgcolor='rgb(54,58,61)',
    plot_bgcolor='rgb(54,58,61)',
    font_color='white'
)

fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
recall_class0 = np.array([0.68, 0.67, 0.68, 0.68, 0.67])
recall_class1 = np.array([0.79, 0.80, 0.79, 0.79, 0.80])

average_recall = (recall_class0 + recall_class1) / 2

fig7 = go.Figure()

fig7.add_trace(go.Bar(
    y=modelos,
    x=recall_class0,
    name='Recall Class 0',
    orientation='h',
    marker_color='#1977D2'
))

fig7.add_trace(go.Bar(
    y=modelos,
    x=recall_class1,
    name='Recall Class 1',
    orientation='h',
    marker_color='#B71C1C'
))

fig7.add_trace(go.Scatter(
    y=modelos,
    x=average_recall,
    mode='lines',
    name='Average Recall',
    line=dict(color='#D4AC0D', width=2)
))

fig7.update_layout(
    title='Comparação de Desempenho dos Modelos',
    xaxis_title='Recall',
    yaxis_title='Modelos',
    yaxis=dict(autorange="reversed"),
    paper_bgcolor='rgb(54,58,61)',
    plot_bgcolor='rgb(54,58,61)',
    font_color='white'
)

fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
f1_scores_class0 = np.array([0.72, 0.72, 0.72, 0.72, 0.72])
f1_scores_class1 = np.array([0.74, 0.75, 0.74, 0.74, 0.75])

average_f1_scores = (f1_scores_class0 + f1_scores_class1) / 2

fig8 = go.Figure()

fig8.add_trace(go.Bar(
    y=modelos,
    x=f1_scores_class0,
    name='F1-Score Class 0',
    orientation='h',
    marker_color='#1977D2'
))

fig8.add_trace(go.Bar(
    y=modelos,
    x=f1_scores_class1,
    name='F1-Score Class 1',
    orientation='h',
    marker_color='#B71C1C'
))

fig8.add_trace(go.Scatter(
    y=modelos,
    x=average_f1_scores,
    mode='lines',
    name='Average F1-Score',
    line=dict(color='#D4AC0D', width=2)
))

fig8.update_layout(
    title='Comparação de Desempenho dos Modelos',
    xaxis_title='F1-Score',
    yaxis_title='Modelos',
    yaxis=dict(autorange="reversed"),
    paper_bgcolor='rgb(54,58,61)',
    plot_bgcolor='rgb(54,58,61)',
    font_color='white'
)

fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Plotando gráfico Accuracy
accuracy = [73, 74, 73, 73, 73]

colors = ['#B71C1C', '#1977D2', '#D4AC0D', '#008080', '#240B3B']

fig9 = go.Figure(
    data=[
        go.Bar(x=modelos, y=accuracy, text=accuracy, textposition='auto', marker={'color': colors})
    ]
)

fig9.update_layout(
    title_text='Comparação da Acurácia dos Modelos',
    xaxis_title='Modelo',
    yaxis_title='Accuracy (%)',
    paper_bgcolor='rgb(54,58,61)',
    plot_bgcolor='rgb(54,58,61)',
    font_color='white')

fig9.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# !pip install jupyter_dash
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = JupyterDash(__name__,external_stylesheets=external_stylesheets)

colors = {
    'background': '#1E1E1E',
    'text': 'white'
}

app.layout = html.Div(
    style={
      'backgroundColor':colors['background'],
      'padding': "10px 40px",
      'borderRadius': "5px"
    },
    children =[

    html.H1(
        children='Casos de Chikungunya',
        style={
          'textAlign':'center',
          'color': colors['text'],
          'fontSize': 32,
          'fontBold': 700,
        }
    ),

    html.P(
        children='''
A presente dashboard consiste em uma interface interativa que exibe informações pertinentes aos casos de chikungunya. Através deste ambiente, é possível acessar alguns gráficos que abordam diferentes aspectos relacionados à referida doença.''',
        style={
          'textAlign':'center',
          'color': colors['text'],
          'fontSize': 16,
          'marginBottom':50
        }
    ),

    html.Div(
      style={
          'display':'flex',
          'alignItens':'center',
          'flexDirection':'column',
          'gap': 20,
      },
      children= [
          dcc.Graph (
            id= 'example.graph',
            figure = fig
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig1
          ),
          dcc.Graph (
              id= 'example.graph',
              figure = fig3
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig2
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig4
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig5
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig6
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig7
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig8
          ),
          dcc.Graph (
            id= 'example.graph',
            figure = fig9
          )          
      ]
    )
  ]
)

# %%
#rodando a aplicação localmente
#cada vez que fizer uma alteraçao na celula de cima rodar essa pra ver na pagina a alteraçao feita
app.run_server(mode='external')
# Out:
# Dash is running on http://127.0.0.1:8050/
# INFO:dash.dash:Dash is running on http://127.0.0.1:8050/
# Dash app running on:
